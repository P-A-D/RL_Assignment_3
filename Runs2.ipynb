# %%
import numpy as np
from Part2 import *

# %% [markdown]
# # Part 1 - Gradient Monte Carlo

# %% [markdown]
# # 10-runs, w = 2

# %% [markdown]
# ## alpha = 0.1, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=2, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.2, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=2, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.3, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=2, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.4, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=2, discount=1, episodes=10000)

# %% [markdown]
# # 10-runs, w = 8

# %% [markdown]
# ## alpha = 0.1, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=8, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.2, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=8, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.3, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=8, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.4, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=8, discount=1, episodes=10000)

# %% [markdown]
# # 10-runs, w = 10

# %% [markdown]
# ## alpha = 0.1, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=10, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.2, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=10, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.3, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=10, discount=1, episodes=10000)

# %% [markdown]
# ## alpha = 0.4, episodes = 1e4, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=10, discount=1, episodes=10000)

# %% [markdown]
# # Part 2 - Semi-gradient TD(0)

# %% [markdown]
# ## 10-runs, w=2, alpha=0.1 to 0.5
#  no stopping until a terminal state is reached

# %%
run_n(SGTD, n=10, alpha=0.1, w_size=2, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.2, w_size=2, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.3, w_size=2, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.4, w_size=2, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.5, w_size=2, discount=1, episodes=1000)

# %% [markdown]
# ## 10-runs, w=8, alpha=0.1 to 0.5
#  no stopping until a terminal state is reached

# %%
run_n(SGTD, n=10, alpha=0.1, w_size=8, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.2, w_size=8, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.3, w_size=8, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.4, w_size=8, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.5, w_size=8, discount=1, episodes=1000)

# %% [markdown]
# ## 10-runs, w=10, alpha=0.1 to 0.5
# no stopping until a terminal state is reached

# %%
run_n(SGTD, n=10, alpha=0.1, w_size=10, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.2, w_size=10, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.3, w_size=10, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.4, w_size=10, discount=1, episodes=1000)

# %%
run_n(SGTD, n=10, alpha=0.5, w_size=10, discount=1, episodes=1000)

# %%
run_n(SGTD, n=100, alpha=0.5, w_size=10, discount=1, episodes=100)

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=2, discount=1, episodes=1000)

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=8, discount=1, episodes=1000)

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=10, discount=1, episodes=1000)

# %% [markdown]
# # Exact value function

# %%
agent = PolicyIteration(discount=1)
v_func = agent.learn()
visualize_results(v_func, "Policy iteration - exact value function")
# Out:
# Iteration count at halt = 2569
