# %%
import numpy as np
from Part2 import *

# %% [markdown]
# # Part 1 - Gradient Monte Carlo

# %% [markdown]
# # Feature count = 10

# %% [markdown]
# ## alpha = 0.1, max length = 20, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=20)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 20, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=20)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.3, max length = 20, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.3, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=20)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.4, max length = 20, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.4, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=20)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")
"""alpha = 0.4 is too high"""

# %% [markdown]
# ## alpha = 0.1, max length = 20, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=10)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=20)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=10)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 13, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=10)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=13)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# # Feature count =8

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=8)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.05, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.05, w_size=8)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=8)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=8)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=8)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# # Feature count = 2

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=2)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=2)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.05, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.05, w_size=2)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.2, w_size=2)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.3, max length = 12, episodes = 1e6

# %%
agent = GradientMonteCarlo(alpha=0.3, w_size=2)
v_func = agent.learn(discount=1, episodes=1000000, max_episode_length=12)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# ## alpha = 0.1, max length = 8, episodes = 1e5

# %%
agent = GradientMonteCarlo(alpha=0.1, w_size=2)
v_func = agent.learn(discount=1, episodes=100000, max_episode_length=8)
visualize_results(v_func, "Gradient Monte Carlo value function estimation")

# %% [markdown]
# # 10-runs, w = 2

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=2, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=2, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.3, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=2, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.4, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=2, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e6, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=2, discount=1, episodes=1000000, max_episode_length=12)

# %% [markdown]
# # 10-runs, w = 8

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=8, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=8, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.3, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=8, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.4, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=8, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e6, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=8, discount=1, episodes=1000000, max_episode_length=12)

# %% [markdown]
# # 10-runs, w = 10

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=10, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.2, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.2, w_size=10, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.3, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.3, w_size=10, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.4, max length = 12, episodes = 1e5, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.4, w_size=10, discount=1, episodes=100000, max_episode_length=12)

# %% [markdown]
# ## alpha = 0.1, max length = 12, episodes = 1e6, n=10

# %%
run_n(GradientMonteCarlo, n=10, alpha=0.1, w_size=10, discount=1, episodes=1000000, max_episode_length=12)

# %% [markdown]
# # Part 2

# %% [markdown]
# # Feature count = 2

# %% [markdown]
# ## alpha = 0.1, episodes = 1e5

# %%
agent = SGTD(alpha=0.1, w_size=2)
v_func = agent.learn(discount=1, episodes=10000)
visualize_results(v_func, "Semi-gradient TD(0) value function estimation")

# %% [markdown]
# ## alpha = 0.2, episodes = 1e5

# %%
agent = SGTD(alpha=0.2, w_size=2)
v_func = agent.learn(discount=1, episodes=10000)
visualize_results(v_func, "Semi-gradient TD(0) value function estimation")

# %% [markdown]
# ## alpha = 0.3, episodes = 1e5

# %%
agent = SGTD(alpha=0.3, w_size=2)
v_func = agent.learn(discount=1, episodes=10000)
visualize_results(v_func, "Semi-gradient TD(0) value function estimation")

# %% [markdown]
# ## alpha = 0.4, episodes = 1e5

# %%
agent = SGTD(alpha=0.4, w_size=2)
v_func = agent.learn(discount=1, episodes=10000)
visualize_results(v_func, "Semi-gradient TD(0) value function estimation")

# %% [markdown]
# ## alpha = 0.5, episodes = 1e5

# %%
agent = SGTD(alpha=0.5, w_size=2)
v_func = agent.learn(discount=1, episodes=10000)
visualize_results(v_func, "Semi-gradient TD(0) value function estimation")

# %% [markdown]
# # 100-runs, w=2, alpha=0.1 to 0.5, episodes=1000, discount=1
#  no stopping until a terminal state is reached

# %%
run_n(SGTD, n=100, alpha=0.1, w_size=2, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.2, w_size=2, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.3, w_size=2, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.4, w_size=2, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.5, w_size=2, discount=1, episodes=1000, max_episode_length=10000)

# %% [markdown]
# # 100-runs, w=8, alpha=0.1 to 0.5, episodes=1000, discount=1
#  no stopping until a terminal state is reached

# %%
run_n(SGTD, n=100, alpha=0.1, w_size=8, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.2, w_size=8, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.3, w_size=8, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.4, w_size=8, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.5, w_size=8, discount=1, episodes=1000, max_episode_length=10000)

# %% [markdown]
# # 100-runs, w=10, alpha=0.1 to 0.5, episodes=1000, discount=1
# no stopping until a terminal state is reached

# %%
run_n(SGTD, n=100, alpha=0.1, w_size=10, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.2, w_size=10, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.3, w_size=10, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.4, w_size=10, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=100, alpha=0.5, w_size=10, discount=1, episodes=1000, max_episode_length=10000)

# %%
run_n(SGTD, n=1000, alpha=0.5, w_size=10, discount=1, episodes=100, max_episode_length=10000)
