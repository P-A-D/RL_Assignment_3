# %%
import numpy as np
from Part1 import *

# %% [markdown]
# # Part 1

# %% [markdown]
# ## Optimal policy estimation -> Sarsa
# ### epsilon = 0.1,  alpha = 0.1

# %%
agent = Sarsa(alpha=0.1)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 0 3 0]
#  [3 3 0 0 0]
#  [3 3 0 2 2]
#  [3 3 0 2 2]]

# %% [markdown]
# ### epsilon = 0.2,  alpha = 0.1

# %%
agent = Sarsa(alpha=0.1)
policy = agent.learn(epsilon=0.2, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 2 0 3 0]
#  [1 1 0 0 2]
#  [1 3 0 2 1]
#  [3 3 0 0 2]]

# %% [markdown]
# ### epsilon = 0.3,  alpha = 0.1

# %%
agent = Sarsa(alpha=0.1)
policy = agent.learn(epsilon=0.3, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 2 3 3 0]
#  [1 0 0 2 2]
#  [1 2 0 2 2]
#  [3 3 3 0 0]]

# %% [markdown]
# ### epsilon = 0.1,  alpha = 0.2

# %%
agent = Sarsa(alpha=0.2)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 2 0 0]
#  [0 1 0 0 3]
#  [3 3 0 2 3]
#  [3 3 0 2 2]]

# %% [markdown]
# ### epsilon = 0.1,  alpha = 0.3

# %%
agent = Sarsa(alpha=0.3)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 3 3 0]
#  [0 2 0 3 0]
#  [3 3 0 2 0]
#  [1 2 0 2 2]
#  [3 3 0 0 3]]

# %% [markdown]
# ### epsilon = 0.2,  alpha = 0.2

# %%
agent = Sarsa(alpha=0.2)
policy = agent.learn(epsilon=0.2, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 0 0 0]
#  [1 3 0 2 1]
#  [3 3 0 2 1]
#  [3 0 2 0 0]]

# %% [markdown]
# ### epsilon = 0.3,  alpha = 0.3

# %%
agent = Sarsa(alpha=0.3)
policy = agent.learn(epsilon=0.3, episode_count=200, discount=0.95)
# Out:
# [[0 2 3 3 0]
#  [0 0 0 0 0]
#  [2 1 0 0 1]
#  [1 2 0 2 1]
#  [2 3 0 2 1]]

# %% [markdown]
# ## Optimal policy estimation -> Q-learning
# ### epsilon = 0.1,  alpha = 0.1

# %%
agent = QLearn(alpha=0.1)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 2 3 3 0]
#  [0 3 0 0 0]
#  [3 3 0 3 1]
#  [3 3 0 1 1]]

# %% [markdown]
# ### epsilon = 0.2,  alpha = 0.1

# %%
agent = QLearn(alpha=0.1)
policy = agent.learn(epsilon=0.2, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 0 0 0]
#  [1 3 0 1 1]
#  [3 3 0 1 3]
#  [0 0 0 1 2]]

# %% [markdown]
# ### epsilon = 0.3,  alpha = 0.1

# %%
agent = QLearn(alpha=0.1)
policy = agent.learn(epsilon=0.3, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 2 2 3 0]
#  [0 2 0 2 0]
#  [3 3 0 2 3]
#  [3 0 0 3 1]]

# %% [markdown]
# ### epsilon = 0.1,  alpha = 0.2

# %%
agent = QLearn(alpha=0.2)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 2 3 0]
#  [1 1 0 3 0]
#  [3 3 0 2 2]
#  [3 3 0 0 1]]

# %% [markdown]
# ### epsilon = 0.1,  alpha = 0.3

# %%
agent = QLearn(alpha=0.3)
policy = agent.learn(epsilon=0.1, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 0 3 0]
#  [3 1 0 1 2]
#  [3 3 0 1 2]
#  [3 0 0 0 3]]

# %% [markdown]
# ### epsilon = 0.2,  alpha = 0.2

# %%
agent = QLearn(alpha=0.2)
policy = agent.learn(epsilon=0.2, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 2 0 0]
#  [3 0 0 0 0]
#  [3 3 0 2 2]
#  [0 0 0 1 0]]

# %% [markdown]
# ### epsilon = 0.3,  alpha = 0.3

# %%
agent = QLearn(alpha=0.3)
policy = agent.learn(epsilon=0.3, episode_count=200, discount=0.95)
# Out:
# [[0 2 2 3 0]
#  [0 0 2 0 0]
#  [0 0 0 1 3]
#  [3 3 0 2 2]
#  [3 0 0 2 1]]
